# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavkatex/The-Internship-2026/blob/main/Tasks/Session%2013/frist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Session 13 (AIML) - Assignment
# Questiont**

# %% [markdown]
# *Q1. (Basic Array Creation)
# Write a program to:
# a) Create a 1D array with elements [10, 20, 30, 40, 50] using np.array().
# b) Create a 2D array (3x3) using np.array().
# Print both arrays along with their shape and data type (dtype).*

# %%
# Importing a Numpy

import numpy as np

# %%
# Creating a 1D array
array1 =np.array([10, 20, 30, 40, 50])
array1
# Out:
# array([10, 20, 30, 40, 50])

# %%
# Creating a 2D array (3 x 3)
array2 = np.array([[1,2,3],[4,5,6],[6,7,8]])
array2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [6, 7, 8]])
